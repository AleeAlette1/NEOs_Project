# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
file_path = "test_data.csv"
df_rf = pd.read_csv(file_path)

# %%
df_rf.head()
# Out:
#      spkid                     full_name pdes                   name prefix  \
# 0  1000004                   85P/Boethin  85P                Boethin      P
# 1  1000009           23P/Brorsen-Metcalf  23P        Brorsen-Metcalf      P
# 2  1000012     67P/Churyumov-Gerasimenko  67P  Churyumov-Gerasimenko      P
# 3  1000016                 27P/Crommelin  27P              Crommelin      P
# 4  1000020          72P/Denning-Fujikawa  72P       Denning-Fujikawa      P
#
#   neo  pha   H  diameter(km) extent(km)  ...  sigma_ma      sigma_ad  \
# 0   Y  NaN NaN           NaN        NaN  ...  0.430000  3.500000e-02
# 1   Y  NaN NaN           NaN        NaN  ...  0.000010  8.300000e-04
# 2   Y  NaN NaN           3.4        NaN  ...  0.000003  8.000000e-08
# 3   Y  NaN NaN           NaN        NaN  ...  0.076000  4.300000e-02
# 4   Y  NaN NaN           NaN        NaN  ...  0.000011  1.500000e-06
#
#         sigma_n  sigma_tp  sigma_per  class  data_arc  n_obs_used  \
# 0  4.800000e-04  8.400000   25.00000    JFc    4042.0          51
# 1  5.200000e-07  0.000028    0.95000    HTC   51904.0         223
# 2  3.200000e-09  0.000021    0.00005    JFc    3547.0        5605
# 3  1.300000e-04  0.004700   38.00000    HTC     259.0         154
# 4  3.100000e-08  0.000082    0.00095    JFc   13080.0          44
#
#    condition_code  rms(arcsec)
# 0             8.0      1.65690
# 1             0.0      1.23470
# 2             0.0      0.57366
# 3             6.0      0.70281
# 4             1.0      1.03990
#
# [5 rows x 43 columns]

# %%
df_rf = df_rf.dropna(subset=['pha'])
df_rf.head()
# Out:
#        spkid                 full_name  pdes     name prefix neo pha      H  \
# 192  2000433        433 Eros (A898 PA)   433     Eros    NaN   Y   N  10.43
# 193  2000719      719 Albert (A911 TB)   719   Albert    NaN   Y   N  15.51
# 194  2000887      887 Alinda (A918 AA)   887   Alinda    NaN   Y   N  13.87
# 195  2001036    1036 Ganymed (A924 UB)  1036  Ganymed    NaN   Y   N   9.25
# 196  2001221      1221 Amor (1932 EA1)  1221     Amor    NaN   Y   N  17.39
#
#      diameter(km)      extent(km)  ...  sigma_ma      sigma_ad       sigma_n  \
# 192        16.840  34.4x11.2x11.2  ...  0.000001  1.900000e-10  9.100000e-11
# 193           NaN             NaN  ...  0.000003  3.900000e-09  3.300000e-10
# 194         4.200             NaN  ...  0.000004  4.700000e-09  4.600000e-10
# 195        37.675             NaN  ...  0.000002  2.900000e-09  2.400000e-10
# 196         1.000             NaN  ...  0.000008  1.300000e-09  2.700000e-10
#
#      sigma_tp     sigma_per  class  data_arc  n_obs_used  condition_code  \
# 192  0.000003  1.000000e-07    AMO   46582.0        9130             0.0
# 193  0.000012  2.300000e-06    AMO   40008.0        1894             0.0
# 194  0.000014  2.600000e-06    AMO   37799.0        2624             0.0
# 195  0.000006  1.700000e-06    AMO   35482.0        7159             0.0
# 196  0.000021  7.000000e-07    AMO   32775.0         573             0.0
#
#      rms(arcsec)
# 192      0.29796
# 193      0.39775
# 194      0.39776
# 195      0.37075
# 196      0.45902
#
# [5 rows x 43 columns]

# %%
df_rf.value_counts(['pha'])
# Out:
# pha
# N      25614
# Y       2213
# dtype: int64

# %%
df_rf.value_counts(['neo'])
# Out:
# neo
# Y      27827
# dtype: int64

# %%
# transform pha to 1 or 0
def change(type):
    if type == "Y":
        return 1
    else:
        return 0

# %%
df_rf["pha"] = df_rf["pha"].apply(change)
df_rf.head()
# Out:
#        spkid                 full_name  pdes     name prefix neo  pha      H  \
# 192  2000433        433 Eros (A898 PA)   433     Eros    NaN   Y    0  10.43
# 193  2000719      719 Albert (A911 TB)   719   Albert    NaN   Y    0  15.51
# 194  2000887      887 Alinda (A918 AA)   887   Alinda    NaN   Y    0  13.87
# 195  2001036    1036 Ganymed (A924 UB)  1036  Ganymed    NaN   Y    0   9.25
# 196  2001221      1221 Amor (1932 EA1)  1221     Amor    NaN   Y    0  17.39
#
#      diameter(km)      extent(km)  ...  sigma_ma      sigma_ad       sigma_n  \
# 192        16.840  34.4x11.2x11.2  ...  0.000001  1.900000e-10  9.100000e-11
# 193           NaN             NaN  ...  0.000003  3.900000e-09  3.300000e-10
# 194         4.200             NaN  ...  0.000004  4.700000e-09  4.600000e-10
# 195        37.675             NaN  ...  0.000002  2.900000e-09  2.400000e-10
# 196         1.000             NaN  ...  0.000008  1.300000e-09  2.700000e-10
#
#      sigma_tp     sigma_per  class  data_arc  n_obs_used  condition_code  \
# 192  0.000003  1.000000e-07    AMO   46582.0        9130             0.0
# 193  0.000012  2.300000e-06    AMO   40008.0        1894             0.0
# 194  0.000014  2.600000e-06    AMO   37799.0        2624             0.0
# 195  0.000006  1.700000e-06    AMO   35482.0        7159             0.0
# 196  0.000021  7.000000e-07    AMO   32775.0         573             0.0
#
#      rms(arcsec)
# 192      0.29796
# 193      0.39775
# 194      0.39776
# 195      0.37075
# 196      0.45902
#
# [5 rows x 43 columns]

# %%
df_rf.columns
# Out:
# Index(['spkid', 'full_name', 'pdes', 'name', 'prefix', 'neo', 'pha', 'H',
#        'diameter(km)', 'extent(km)', 'albedo', 'rot_per', 'eccentricity',
#        'semi_major_axis(au)', 'q(au)', 'inclination(deg)',
#        'long_ascending_node(deg)', 'argument_perihelion(deg)',
#        'mean_anomaly(deg)', 'aphelion_distance(au)', 'mean_motion(dge/d)',
#        'per(d)', 'per.y(year)', 'moid(au)', 'moid.ld(LD)', 'moid_jup(au)',
#        't_jup', 'sigma_e', 'sigma_a', 'sigma_q', 'sigma_i', 'sigma_om',
#        'sigma_w', 'sigma_ma', 'sigma_ad', 'sigma_n', 'sigma_tp', 'sigma_per',
#        'class', 'data_arc', 'n_obs_used', 'condition_code', 'rms(arcsec)'],
#       dtype='object')

# %%
# create several csv's, drop not needed columns
df = df_rf.drop(columns=['pdes', 'full_name', 'name', 'prefix', 'neo'])
df
# Out:
#           spkid  pha      H  diameter(km)      extent(km)  albedo  rot_per  \
# 192     2000433    0  10.43        16.840  34.4x11.2x11.2   0.250    5.270
# 193     2000719    0  15.51           NaN             NaN     NaN    5.801
# 194     2000887    0  13.87         4.200             NaN   0.310   28.410
# 195     2001036    0   9.25        37.675             NaN   0.238   10.297
# 196     2001221    0  17.39         1.000             NaN     NaN      NaN
# ...         ...  ...    ...           ...             ...     ...      ...
# 28047  54235471    1  20.70           NaN             NaN     NaN      NaN
# 28048  54235472    0  25.50           NaN             NaN     NaN      NaN
# 28049  54235473    0  23.30           NaN             NaN     NaN      NaN
# 28050  54235474    0  24.51           NaN             NaN     NaN      NaN
# 28051  54235475    0  24.96           NaN             NaN     NaN      NaN
#
#        eccentricity  semi_major_axis(au)  q(au)  ...  sigma_ma      sigma_ad  \
# 192          0.2227               1.4580  1.133  ...  0.000001  1.900000e-10
# 193          0.5470               2.6380  1.195  ...  0.000003  3.900000e-09
# 194          0.5705               2.4730  1.062  ...  0.000004  4.700000e-09
# 195          0.5331               2.6660  1.245  ...  0.000002  2.900000e-09
# 196          0.4358               1.9190  1.082  ...  0.000008  1.300000e-09
# ...             ...                  ...    ...  ...       ...           ...
# 28047        0.5464               1.7620  0.799  ...  0.510000  2.900000e-02
# 28048        0.3402               0.8315  0.549  ...  0.400000  1.600000e-03
# 28049        0.5449               1.4670  0.668  ...  0.470000  1.700000e-02
# 28050        0.6016               2.2050  0.878  ...  0.160000  3.100000e-02
# 28051        0.1517               0.9547  0.810  ...  0.550000  1.100000e-03
#
#             sigma_n  sigma_tp     sigma_per  class  data_arc  n_obs_used  \
# 192    9.100000e-11  0.000003  1.000000e-07    AMO   46582.0        9130
# 193    3.300000e-10  0.000012  2.300000e-06    AMO   40008.0        1894
# 194    4.600000e-10  0.000014  2.600000e-06    AMO   37799.0        2624
# 195    2.400000e-10  0.000006  1.700000e-06    AMO   35482.0        7159
# 196    2.700000e-10  0.000021  7.000000e-07    AMO   32775.0         573
# ...             ...       ...           ...    ...       ...         ...
# 28047  6.600000e-03  0.140000  1.300000e+01    APO       2.0          52
# 28048  2.800000e-03  0.250000  6.000000e-01    ATE       1.0          27
# 28049  6.400000e-03  0.180000  7.500000e+00    APO       1.0          27
# 28050  4.000000e-03  0.056000  1.600000e+01    APO       1.0          24
# 28051  1.700000e-03  0.350000  5.300000e-01    ATE       1.0          15
#
#        condition_code  rms(arcsec)
# 192               0.0      0.29796
# 193               0.0      0.39775
# 194               0.0      0.39776
# 195               0.0      0.37075
# 196               0.0      0.45902
# ...               ...          ...
# 28047             9.0      0.35793
# 28048             8.0      0.49332
# 28049             9.0      0.20312
# 28050             9.0      0.47646
# 28051             8.0      0.41222
#
# [27827 rows x 38 columns]

# %%
# create different groups
g1 = ['spkid', 'pha', 'H', 'diameter(km)', 'extent(km)', 'albedo', 'rot_per']
g2 = ['spkid', 'pha', 'eccentricity', 'semi_major_axis(au)', 'q(au)', 'inclination(deg)', 'long_ascending_node(deg)', 'argument_perihelion(deg)', 'mean_anomaly(deg)', 'aphelion_distance(au)']
g3 = ['spkid', 'pha', 'sigma_e', 'sigma_a', 'sigma_q', 'sigma_i', 'sigma_om', 'sigma_w', 'sigma_ma', 'sigma_ad', 'sigma_n', 'sigma_tp', 'sigma_per',]

# %% [markdown]
# Looks like diameter, extent, albedo, and rot_per have too much NAN.  Will not use ds1 in RF.

# %%
ds1 = df[g1]
ds2 = df[g2]
ds3 = df[g3]

# %%
ds1.isnull().sum()
# Out:
# spkid               0
# pha                 0
# H                   4
# diameter(km)    26579
# extent(km)      27818
# albedo          26624
# rot_per         25945
# dtype: int64

# %%
#ds1 = ds1.dropna()
ds2 = ds2.dropna()
ds3 = ds3.dropna()

# %%
ds1.info()
ds2.info()
ds3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27827 entries, 192 to 28051
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   spkid         27827 non-null  int64
#  1   pha           27827 non-null  int64
#  2   H             27823 non-null  float64
#  3   diameter(km)  1248 non-null   float64
#  4   extent(km)    9 non-null      object
#  5   albedo        1203 non-null   float64
#  6   rot_per       1882 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 1.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27827 entries, 192 to 28051
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   spkid                     27827 non-null  int64
#  1   pha                       27827 non-null  int64
#  2   eccentricity              27827 non-null  float64
#  3   semi_major_axis(au)       27827 non-null  float64
#  4   q(au)                     27827 non-null  float64
#  5   inclination(deg)          27827 non-null  float64
#  6   long_ascending_node(deg)  27827 non-null  float64
#  7   argument_perihelion(deg)  27827 non-null  float64
#  8   mean_anomaly(deg)         27827 non-null  float64
#  9   aphelion_distance(au)     27827 non-null  float64
# dtypes: float64(8), int64(2)
# memory usage: 2.3 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27827 entries, 192 to 28051
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   spkid      27827 non-null  int64
#  1   pha        27827 non-null  int64
#  2   sigma_e    27827 non-null  float64
#  3   sigma_a    27827 non-null  float64
#  4   sigma_q    27827 non-null  float64
#  5   sigma_i    27827 non-null  float64
#  6   sigma_om   27827 non-null  float64
#  7   sigma_w    27827 non-null  float64
#  8   sigma_ma   27827 non-null  float64
#  9   sigma_ad   27827 non-null  float64
#  10  sigma_n    27827 non-null  float64
#  11  sigma_tp   27827 non-null  float64
#  12  sigma_per  27827 non-null  float64
# dtypes: float64(11), int64(2)
# memory usage: 3.0 MB

# %%
# Saving cleaned data
#file_path = "ds1_cleaned.csv"
#ds1.to_csv(file_path, index=False)
# Saving cleaned data
file_path = "ds2_cleaned.csv"
ds2.to_csv(file_path, index=False)
# Saving cleaned data
file_path = "ds3_cleaned.csv"
ds3.to_csv(file_path, index=False)
